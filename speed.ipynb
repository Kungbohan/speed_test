# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.style.use('ggplot')

Threads = [1,2,12,24,60,120]
speed = [97.54, 51.42, 8.96, 7.75, 10.06, 38.3]

GPU = [1]
GPU_speed = [0.4082]

plt.plot(Threads, speed, marker='o', label='CPU')
plt.plot(GPU, GPU_speed, marker='s', label='GPU')  
# plt.axhline(y = 0.4082, color = 'green', linestyle = '-', label='GPU')   

plt.legend()
plt.ylabel('Time cost (log scale)')
plt.yscale("log")
plt.xlabel('Number of threads')
# Out:
# Text(0.5, 0, 'Number of threads')
